# %%
import glob as glob
from pathlib import Path
import urllib

# %%
gpx_numbers=[ Path(x).stem for x in sorted(glob.glob('./gpxs/*.gpx'))]

# %%
def url_builder(gpx_numbers):
    
    #url_start='https://gpx.studio/app?files=%5B%22https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F%s.gpx'%gpx_numbers[0]
    url_start='https://gpx.studio/app?files='+ urllib.parse.quote("""["https://rdspt.com/inlawsgravel/gpxs/%s.gpx"""%gpx_numbers[0])
    url= url_start
    for g in gpx_numbers[1:]:
        #url = url + "%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F%s.gpx"%g
        url = url + urllib.parse.quote(""""," https://rdspt.com/inlawsgravel/gpxs/%s.gpx"""%g)
        
    url_end ="%22%5D#10.31/50.7281/7.1587"
    
    url = url + url_end
    return url

# %%
u = url_builder(gpx_numbers)

u
# Out:
# 'https://gpx.studio/app?files=%5B%22https%3A//rdspt.com/inlawsgravel/gpxs/001.gpx%22%2C%22%20https%3A//rdspt.com/inlawsgravel/gpxs/002.gpx%22%2C%22%20https%3A//rdspt.com/inlawsgravel/gpxs/003.gpx%22%2C%22%20https%3A//rdspt.com/inlawsgravel/gpxs/004.gpx%22%2C%22%20https%3A//rdspt.com/inlawsgravel/gpxs/005.gpx%22%2C%22%20https%3A//rdspt.com/inlawsgravel/gpxs/006.gpx%22%2C%22%20https%3A//rdspt.com/inlawsgravel/gpxs/007.gpx%22%2C%22%20https%3A//rdspt.com/inlawsgravel/gpxs/008.gpx%22%2C%22%20https%3A//rdspt.com/inlawsgravel/gpxs/009.gpx%22%2C%22%20https%3A//rdspt.com/inlawsgravel/gpxs/010.gpx%22%2C%22%20https%3A//rdspt.com/inlawsgravel/gpxs/011.gpx%22%2C%22%20https%3A//rdspt.com/inlawsgravel/gpxs/012.gpx%22%2C%22%20https%3A//rdspt.com/inlawsgravel/gpxs/013.gpx%22%2C%22%20https%3A//rdspt.com/inlawsgravel/gpxs/014.gpx%22%2C%22%20https%3A//rdspt.com/inlawsgravel/gpxs/015.gpx%22%2C%22%20https%3A//rdspt.com/inlawsgravel/gpxs/016.gpx%22%2C%22%20https%3A//rdspt.com/inlawsgravel/gpxs/017.gpx%22%2
# ...

# %%
https://gpx.studio/app?files=%5B%22https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F030.gpx
                       %22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F029.gpx
                       %22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F028.gpx
                       %22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F027.gpx
                       %22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F026.gpx
                       %22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F025.gpx
                       %22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F024.gpx%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F023.gpx%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F022.gpx%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F021.gpx%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F020.gpx%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F019.gpx%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F018.gpx%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F017.gpx%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F016.gpx%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F015.gpx%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F014.gpx%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F013.gpx%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F012.gpx%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F011.gpx%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F010.gpx%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F009.gpx%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F008.gpx%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F007.gpx%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F006.gpx%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F005.gpx%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F004.gpx%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F003.gpx%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F002.gpx
                       %22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F001.gpx%22%5D#10.31/50.7281/7.1587
# Out:
#   File "<ipython-input-5-e36ac0fd3771>", line 1
#     https://gpx.studio/app?files=%5B%22https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F030.gpx
#           ^
# SyntaxError: invalid syntax

# %%
# todo 
# - url encode

# %%
urllib.parse.quote("""https://gpx.studio/app?files=["https://rdspt.com/inlawsgravel/gpxs/%s.gpx"""%2)
# Out:
# 'https%3A//gpx.studio/app%3Ffiles%3D%5B%22https%3A//rdspt.com/inlawsgravel/gpxs/2.gpx'

# %%
urllib.parse.unquote('%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F%s.gpx'%2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-12f062e6bd44> in <module>
# ----> 1 urllib.parse.unquote('%22%2C%22%20https%3A%2F%2Frdspt.com%2Finlawsgravel%2Fgpxs%2F%s.gpx'%2)
#
# ValueError: unsupported format character '%' (0x25) at index 3
